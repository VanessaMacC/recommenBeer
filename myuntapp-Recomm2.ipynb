# %%
import pandas as pd
import numpy as np

import ipywidgets as widgets
from ipywidgets import interactive

# %%
beers = pd.read_csv("./data/myuntapp.csv", engine = 'python')

# %%
beers.shape
# Out:
# (2365, 32)

# %%
beers.columns
# Out:
# Index(['beer_name', 'brewery_name', 'beer_type', 'beer_abv', 'beer_ibu',
#        'comment', 'venue_name', 'venue_city', 'venue_state', 'venue_country',
#        'venue_lat', 'venue_lng', 'rating_score', 'created_at', 'checkin_url',
#        'beer_url', 'brewery_url', 'brewery_country', 'brewery_city',
#        'brewery_state', 'flavor_profiles', 'purchase_venue', 'serving_type',
#        'checkin_id', 'bid', 'brewery_id', 'photo_url', 'global_rating_score',
#        'global_weighted_rating_score', 'tagged_friends', 'total_toasts',
#        'total_comments'],
#       dtype='object')

# %%
beers.isna().sum()
# Out:
# beer_name                          0
# brewery_name                       0
# beer_type                          0
# beer_abv                           0
# beer_ibu                           0
# comment                         2212
# venue_name                      1223
# venue_city                      1253
# venue_state                     1240
# venue_country                   1228
# venue_lat                       1223
# venue_lng                       1223
# rating_score                       0
# created_at                         0
# checkin_url                        0
# beer_url                           0
# brewery_url                        0
# brewery_country                    0
# brewery_city                      63
# brewery_state                    124
# flavor_profiles                 1958
# purchase_venue                  2312
# serving_type                    1921
# checkin_id                         0
# bid                                0
# brewery_id                         0
# photo_url                        450
# global_rating_score                0
# global_weighted_rating_score       0
# tagged_friends                  2275
# total_toasts                       0
# total_comments                     0
# dtype: int64

# %%
beers = beers[['beer_name', 'brewery_name', 'beer_type', 'beer_abv', 'beer_ibu', 
               'venue_name', 'venue_city', 'venue_state', 'venue_country',
               'venue_lat', 'venue_lng', 'rating_score', 'created_at', 'checkin_url',
               'beer_url', 'brewery_url', 'brewery_country', 'brewery_city',
               'brewery_state', 'flavor_profiles', 'purchase_venue', 'serving_type',
               'checkin_id', 'bid', 'brewery_id', 'photo_url', 'global_rating_score',
               'global_weighted_rating_score']]

# %%
beers = beers.fillna(0)

# %%
beers.tail()
# Out:
#                   beer_name        brewery_name  \
# 2360           Soda Pop IPA       Vega Bryggeri
# 2361    Sitting Bulldog IPA   Gotlands Bryggeri
# 2362             Boogie IPA    Duckpond Brewing
# 2363                Essence   Ten Hands Brewing
# 2364  Norrlands Guld (3.5%)  Spendrups Bryggeri
#
#                               beer_type  beer_abv  beer_ibu  \
# 2360  IPA - Session / India Session Ale       3.5        20
# 2361                     IPA - American       6.4        45
# 2362                  IPA - New England       6.4         0
# 2363                  IPA - New England       6.0        40
# 2364                       Lager - Pale       3.5         0
#
#              venue_name venue_city           venue_state venue_country  \
# 2360                  0          0                     0             0
# 2361  Wärdshuset Tullen   Göteborg  Västra Götalands län       Sverige
# 2362           Beerista   Göteborg  Västra Götalands län       Sverige
# 2363           Beerista   Göteborg  Västra Götalands län       Sverige
# 2364                  0          0                     0             0
#
#       venue_lat  ...         brewery_state           flavor_profiles  \
# 2360     0.0000  ...                     0      tropical,hoppy,Candy
# 2361    57.6991  ...          Gotlands län              fruity,hoppy
# 2362    57.7002  ...  Västra Götalands län  piney,fruity,hoppy,juicy
# 2363    57.7002  ...                     0    tropical,fruity,citrus
# 2364     0.0000  ...                     0                light,thin
#
#       purchase_venue serving_type checkin_id      bid brewery_id  \
# 2360  LiDL Vasagatan       Bottle  950408488  3744174      30350
# 2361               0        Draft  950451889    31794       3331
# 2362               0          Can  950465330  3332130     437848
# 2363               0          Can  950465963  3739187     424669
# 2364               0          Can  950851020    52902       1505
#
#                                               photo_url global_rating_score  \
# 2360  https://untappd.s3.amazonaws.com/photos/2020_1...                3.05
# 2361  https://untappd.s3.amazonaws.com/photos/2020_1...                3.48
# 2362  https://untappd.s3.amazonaws.com/photos/2020_1...                3.71
# 2363  https://untappd.s3.amazonaws.com/photos/2020_1...                3.72
# 2364  https://untappd.s3.amazonaws.com/photos/2020_1...                2.48
#
#      global_weighted_rating_score
# 2360                         3.13
# 2361                         3.49
# 2362                         3.70
# 2363                         3.71
# 2364                         2.50
#
# [5 rows x 28 columns]

# %%
pd.value_counts(beers['beer_type'], sort = True).head(30)
# Out:
# IPA - American                       381
# Pale Ale - American                  141
# Lager - Pale                         134
# IPA - Imperial / Double              107
# IPA - Session / India Session Ale     93
# Pilsner - Other                       63
# IPA - New England                     53
# Lager - Euro Pale                     48
# Stout - Imperial / Double             40
# Farmhouse Ale - Saison                38
# Sour - Other                          37
# Red Ale - American Amber / Red        34
# IPA - English                         34
# Hefeweizen                            34
# Pilsner - Czech                       31
# Blonde Ale                            29
# Sour - Fruited Berliner Weisse        27
# Wheat Beer - Witbier                  26
# Stout - Russian Imperial              25
# Gluten-Free                           24
# Pale Ale - English                    24
# Belgian Tripel                        24
# Pilsner - German                      23
# Sour - Fruited Gose                   22
# IPA - International                   22
# Lambic - Gueuze                       22
# Lager - Helles                        20
# Pale Ale - International              19
# Belgian Blonde                        19
# Sour - Berliner Weisse                19
# Name: beer_type, dtype: int64

# %%
df=beers.copy()

# %%
df.columns
# Out:
# Index(['beer_name', 'brewery_name', 'beer_type', 'beer_abv', 'beer_ibu',
#        'venue_name', 'venue_city', 'venue_state', 'venue_country', 'venue_lat',
#        'venue_lng', 'rating_score', 'created_at', 'checkin_url', 'beer_url',
#        'brewery_url', 'brewery_country', 'brewery_city', 'brewery_state',
#        'flavor_profiles', 'purchase_venue', 'serving_type', 'checkin_id',
#        'bid', 'brewery_id', 'photo_url', 'global_rating_score',
#        'global_weighted_rating_score'],
#       dtype='object')

# %%
df=df[['beer_name','beer_type','beer_abv','beer_ibu','rating_score','global_rating_score','photo_url']]
df.head()
# Out:
#           beer_name                  beer_type  beer_abv  beer_ibu  \
# 0   Strong Pale Ale       Strong Ale - English       6.2         0
# 1        Ambar 1900         Pale Ale - English       4.8        21
# 2          Tsingtao               Lager - Pale       4.7        25
# 3  It's StillWeisse     Sour - Berliner Weisse       3.0         0
# 4  La Chouffe Blond  Belgian Strong Golden Ale       8.0        20
#
#    rating_score  global_rating_score  \
# 0          3.25                 3.36
# 1          2.00                 2.87
# 2          2.50                 2.87
# 3          3.50                 3.39
# 4          4.50                 3.84
#
#                                            photo_url
# 0  https://untappd.s3.amazonaws.com/photo/2013_11...
# 1  https://untappd.s3.amazonaws.com/photo/2013_11...
# 2  https://untappd.s3.amazonaws.com/photo/2013_11...
# 3  https://untappd.s3.amazonaws.com/photo/2013_11...
# 4  https://untappd.s3.amazonaws.com/photo/2013_11...

# %%
#df.to_csv(r'./data/df.csv',index=False,header=True)

# %%
ratings = df.pivot_table(values='rating_score', index='beer_type', columns='beer_name')
ratings.fillna(0, inplace=True)
beer_index = ratings.columns
ratings.shape
# Out:
# (164, 2010)

# %%
ratings.head()
# Out:
# beer_name                  Amber Lager (Jantarový ležák)  \
# beer_type
# Altbier                                              0.0
# American Wild Ale                                    0.0
# Australian Sparkling Ale                             0.0
# Barleywine - American                                0.0
# Barleywine - English                                 0.0
#
# beer_name                  Celebration Lager (Sváteční ležák)  #poundsign  \
# beer_type
# Altbier                                                   0.0         0.0
# American Wild Ale                                         0.0         0.0
# Australian Sparkling Ale                                  0.0         0.0
# Barleywine - American                                     0.0         0.0
# Barleywine - English                                      0.0         0.0
#
# beer_name                 ...Zest Please!  \
# beer_type
# Altbier                               0.0
# American Wild Ale                     0.0
# Australian Sparkling Ale              0.0
# Barleywine - American                 0.0
# Barleywine - English                  0.0
#
# beer_name                 05|11 - India Pale Ale - Citra & Mosaic  100  \
# beer_type
# Altbier                                                       0.0  0.0
# American Wild Ale                                             0.0  0.0
# Australian Sparkling Ale                                      0.0  0.0
# Barleywine - American                                         0.0  0.0
# Barleywine - English                                          0.0  0.0
#
# beer_name                 1000 IPA  100W  \
# beer_type
# Altbier                        0.0   0.0
# American Wild Ale              0.0   0.0
# Australian Sparkling Ale       0.0   0.0
# Barleywine - American          0.0   0.0
# Barleywine - English           0.0   0.0
#
# beer_name                 11|15 Session IPA - Amarillo & Mosaic  \
# beer_type
# Altbier                                                     0.0
# American Wild Ale                                           0.0
# Australian Sparkling Ale                                    0.0
# Barleywine - American                                       0.0
# Barleywine - English                                        0.0
#
# beer_name                 11|21 - Session IPA - Mosaic & Wai-iti  ...  \
# beer_type                                                         ...
# Altbier                                                      0.0  ...
# American Wild Ale                                            0.0  ...
# Australian Sparkling Ale                                     0.0  ...
# Barleywine - American                                        0.0  ...
# Barleywine - English                                         0.0  ...
#
# beer_name                 ¡Buena Para El Papa! ¿Si, No?  Ámbar  \
# beer_type
# Altbier                                             0.0    0.0
# American Wild Ale                                   0.0    0.0
# Australian Sparkling Ale                            0.0    0.0
# Barleywine - American                               0.0    0.0
# Barleywine - English                                0.0    0.0
#
# beer_name                 Únětické Pivo 10°  \
# beer_type
# Altbier                                 0.0
# American Wild Ale                       0.0
# Australian Sparkling Ale                0.0
# Barleywine - American                   0.0
# Barleywine - English                    0.0
#
# beer_name                 Überschlag IPA (Belgian Style Flashover IPA)  \
# beer_type
# Altbier                                                            0.0
# American Wild Ale                                                  0.0
# Australian Sparkling Ale                                           0.0
# Barleywine - American                                              0.0
# Barleywine - English                                               0.0
#
# beer_name                 Übersee Hopfen  Łomża Jasne  Żubr  Żywiec  \
# beer_type
# Altbier                              0.0          0.0   0.0     0.0
# American Wild Ale                    0.0          0.0   0.0     0.0
# Australian Sparkling Ale             0.0          0.0   0.0     0.0
# Barleywine - American                0.0          0.0   0.0     0.0
# Barleywine - English                 0.0          0.0   0.0     0.0
#
# beer_name                 Комета IPA   √225 Saison
# beer_type
# Altbier                           0.0          0.0
# American Wild Ale                 0.0          0.0
# Australian Sparkling Ale          0.0          0.0
# Barleywine - American             0.0          0.0
# Barleywine - English              0.0          0.0
#
# [5 rows x 2010 columns]

# %%
list(ratings.columns)
# Out:
# [' Amber Lager (Jantarový ležák)',
#  ' Celebration Lager (Sváteční ležák)',
#  '#poundsign',
#  '...Zest Please!',
#  '05|11 - India Pale Ale - Citra & Mosaic',
#  '100',
#  '1000 IPA',
#  '100W',
#  '11|15 Session IPA - Amarillo & Mosaic',
#  '11|21 - Session IPA - Mosaic & Wai-iti',
#  '1349 Pale Ale',
#  '15 Hours Amarillo',
#  '15 Hours Session IPA - Ahtanum',
#  '15 Hours Session IPA - Nelson Sauvin',
#  '15 Hours Session IPA Mosaic',
#  '15 Hours Session IPA Simcoe',
#  '15&30 Sherry Cask Blond',
#  '15&30 Sherry Cask IPA',
#  '1500',
#  '1698',
#  '18/70',
#  '18|04 Farmhouse - Gose',
#  '19',
#  '1906 Reserva Especial',
#  '1969 IPA (Remember Series)',
#  '1970 IPA (Remember Series)',
#  '2 Tone - Imperial Sour Porter',
#  '2-Year Unblended Oude Lambiek Foeder #53',
#  '2.0',
#  '20',
#  '2017 Project Barista: CapHeine',
#  '21|07 - Pale Ale - NZ Cascade',
#  '21|Pale Ale - Citra',
#  '25',
#  '3 Fonteinen Oude Geuze',
#  '3 MONTS',
#  '312 Urban Wheat Ale',
#  '333 Premium Export',
#  '35K',
#  '360',
#  '3x Thirsty Mosaic',
#  '40th Hoppy Anniversary Ale',
#  '5 Ronin',
#  '50/50: Mosaic/Citra',
#  '5AM Saint',
#  '6th Anniversary LaGrúa',
#  '7 Hop IPA',
#  '70K',
#  '75 Day Lager',
#  '7:45 Escalation',
#  '7th Anniversary La Grúa',
#  '8-Ball Rye IPA',
#  '8.6 Original',
#  '888',
#  '8th Day (8η Μέρα)',
#  '9 Maltas',
#  '909 Imperial IPA',
#  '942',
#  '942 IPA',
#  'A Beer (Discontinued Version)',
#  'A Face With No Name',
#  'A Fierce Scotsman In Brew York',
#  'A.K. DAMM',
#  'AC/DC Premium Lager',
#  'ALABAMA SLAMMER Moonshiner Series',
#  'ART23 Kiwi & Cherry Berliner Weisse',
#  'ART29 Florida IPA',
#  'ART8 Berliner Weisse Strawberry',
#  'AUPA',
#  'AWAMBA BULUBA',
#  "Abbaye d'Aulne Blonde",
#  'Abbaye de Saint Bon-Chien',
#  'Abordaia',
#  'Abril',
#  'Abstract',
#  'Abt 12',
#  'Accidental Jedi',
#  'Ace of Equinox',
#  'Adlerbrau Tipo Pilsen',
#  'Adlerkönig Urtyp Hell',
#  'Adriaan Wit',
#  'Adriaen Brouwer Dark Gold',
#  'Aecht Schlenkerla Eiche - Doppelbock',
#  'Aecht Schlenkerla Rauchbier - Märzen',
#  'Aecht Schlenkerla Rauchbier - Urbock',
#  'Aecht Schlenkerla Rauchbier - Weizen',
#  'Aeg Maha',
#  'Aerialist Spring Lager',
#  'Aestate',
#  'Affligem Blonde',
#  'Affligem Dubbel',
#  'Affligem Tripel',
#  'Affumicator',
#  'Aftermath IPA',
#  'Akelarre',
#  'Aker',
#  'Akira',
#  'Aktien Original 1857',
#  'Aldersbacher Kloster Dunkel',
#  'Alexander (2016)',
#  'Alfa (Άλφα) Beer',
#  'Alfa Edel Pils',
#  'Alfa Ongefilterd Puur',
#  'Alhambra Especial',
#  'Alhambra Negra',
#  'Alhambra Reserva 1925',
#  'Alhambra Reserva Roja',
#  'Alhambra Sin Alcohol',
#  'Alhambra Tradicional',
#  'Aliada Lager',
#  'Alice The Dog',
#  'Alien Klaw',
#  'All Day IPA',
#  'All Other Pales Pale',
#  'Almost Kriek',
#  'Aloysius',
#  'Alpha',
#  'Alpha Centauri Binary IPA',
#  'Alternator IPA',
#  'Altvater Weissbierbock',
#  'Amarillo / Storm & Bliksem',
#  'Ambar 1900',
#  'Ambar CaesarAvgvsta',
#  'Ambar Especial',
#  'Ambar Export',
#  'Amber',
#  'Amber Ale',
#  'American Amber Ale',
#  'American Black IPA',
#  'American Brown Ale',
#  'American IPA',
#  'American Pale',
#  'American Pale Ale',
#  'Americano A Roma',
#  'Amoor',
#  'Amstel',
#  'Amstel 0.0',
#  'Amstel Extra',
#  'Amstel Oro',
#  'Amun',
#  'Amura',
#  'Ancho Dark Lager',
#  'Anchor IPA',
#  'Anchor Porter',
#  'Anchor Steam Beer',
#  'Andaluza Pale Ale',
#  'Andechser Weissbier Hell',
#  'Angelus Hoppy Pils',
#  'Ani',
#  'Antipodius',
#  'Antoñita "La Moderna"',
#  'Aotearoa',
#  'Apatxe',
#  'Apocalyptic Thunder Juice',
#  'Arany Ászok',
#  'Arapiles',
#  'Arcade Nation',
#  'Archi',
#  'Arctic SunStone',
#  'Argus',
#  'Arizona Beast',
#  'Arrogant Bastard Ale',
#  'Asahi Super Dry',
#  'Asteroid 56013',
#  'Atlantic Ale',
#  'Atlas',
#  'Atlântida',
#  'Atocha',
#  'Atomic',
#  'Aunt Mary',
#  'Aurea',
#  'Aurora',
#  'Aurora Hoppyalis IPA',
#  'Aurum Iberica Pilsen',
#  'Aurum Ibérica Special',
#  'Autumnal',
#  'Axe Edge',
#  'Ayinger Urweisse',
#  'Ayinger Weizenbock',
#  'Azacca IPA',
#  'Azala',
#  'B-Bomb (2016)',
#  'B-Moor',
#  'BNN',
#  'Baby Daddy Session IPA',
#  'Bakalář Světlý ležák',
#  'Balatonvilágosi',
#  'Baltika #5 Gold / Балтика #5 Золотое',
#  'Baltika #7 Export / Балтика #7 Экспортное',
#  'Baltika #9 Strong / Балтика #9 Крепкое',
#  'Bammetjes Bier',
#  'Bang! Bang!',
#  'Barbarian IPA',
#  'Barista Chocolate Quad',
#  'Barretina',
#  'Barrica',
#  'Basatia',
#  'Bataille',
#  'Batch #200',
#  'Batch 1000',
#  'Bavaria 0.0% Wit',
#  'Bearded Lady Grand Marnier Chocolate Orange (2016)',
#  "Beck's",
#  "Beck's Non-Alcoholic / Alkoholfrei / Blue",
#  'Beer Watch Winter',
#  'Beer4Wedding Tontaube Nødutgang',
#  'BeerBera',
#  'BeerBrugna',
#  'Beersel Zwet.be',
#  'Belgian Amber Ale',
#  'Belgian Rye Fruit APA Mango Citra',
#  'Belgian White',
#  'Bellerose Blonde',
#  'Ben',
#  'Benedictina',
#  'Benediktiner Weissbier',
#  'Bengal',
#  'Bengali',
#  'Berliner Framboos-Raspberry',
#  'Berliner Guais',
#  'Bermeja',
#  'Bernard IPA',
#  'Bernard s Těžkou Hlavou OX',
#  'Berry Enchantress',
#  'Best Bitter',
#  'Best Coast IPA',
#  'Better Half',
#  'Betty Juice',
#  'Bibble',
#  'Bible Belt',
#  'Bienvenido',
#  'BierCaB Pale Ale',
#  'Big A IPA',
#  'Big Bear Black Stout™',
#  'Big Beñat (Cerveza Solidaria)',
#  'Big Daddy IPA',
#  'Big Job',
#  'Big Swell IPA',
#  'Bigmouth',
#  'Birdo',
#  'Birra Ichnusa',
#  "Birra Moretti L'Autentica",
#  'Bishops Finger',
#  'Bitburger Pils 0.0 Drive',
#  "Bitches' Bank",
#  'Bitter',
#  'Black & Molen',
#  'Black Chocolate Stout',
#  'Black Currant',
#  'Black Damnation II - Mocha Bomb',
#  'Black Garlic',
#  'Black IPA',
#  'Black Maiden (Cover Series)',
#  'Black Malts & Body Salts',
#  'Black Mamba',
#  'Black Maria',
#  'Black Planet',
#  'Black Shark',
#  'Black Soul',
#  'Blackcyl',
#  'Blaecorn Unidragon',
#  'Blanca',
#  'Blanche de Bruxelles',
#  'Blanche de Charleroi',
#  'Blanche de Namur',
#  'Blanka Tigro',
#  'Blind Cowboy',
#  'Blind Cowboy Edición Especial',
#  'Blommer I Madeira',
#  'Blond IPA',
#  'Blonde Ale',
#  'Blood Orange Gose',
#  'Blood Orange IPA',
#  'Bloodline Blood Orange Ale',
#  "Bloody 'Ell",
#  'Bloody Show',
#  'Blossom',
#  'Blow Pop',
#  'Blue Velvet',
#  'Blueberry Sour',
#  'Bohemian Lager (Světlý ležák 12)',
#  'Bohío',
#  'Boira',
#  'Boise',
#  'Bolleke De Koninck (APA)',
#  'Bomb!',
#  'Bombardier Amber Beer/Premium British Ale (Glorious English Ale)',
#  'Bombardier Golden Beer',
#  'Bomber IPA ',
#  'Bombo Claat',
#  'Bomschuit',
#  'Bonaparte',
#  'Bonita',
#  'Boo Koo',
#  'Boogie IPA',
#  'Booming Rollers',
#  'Boondoggle',
#  'Boris the Butcher',
#  'Born In the IPA',
#  'Born To Die 14.05.2016',
#  'Borsodi',
#  'Bourgogne des Flandres Brune / Bruin',
#  'Brahma (4.3%)',
#  'Braskadi',
#  'Bratislavský Bubák 12°',
#  'Bratislavský ležiak 12°',
#  'Brave New World',
#  'Breakfast Stout',
#  'Breakwater',
#  'Brett Peat Daydream',
#  'Brettasaurus',
#  'Brettxit',
#  'BrevArt',
#  'Bright Lies',
#  'Bringer of Summer',
#  "Brink's Blonde",
#  'Broadside',
#  'Broadside Strong Original',
#  'Broeder Jacob Tripel',
#  'Brooklyn Brown Ale',
#  'Brooklyn East IPA',
#  'Brooklyn Lager',
#  'Brooklyn Sorachi Ace',
#  'Brooklyn Summer Ale',
#  'Brown Ale',
#  'Brugs Witbier / Blanche de Bruges',
#  'Brugse Zot',
#  'Brunehaut Ambrée Organic & Gluten Free',
#  'Brunehaut Blanche Organic & Gluten Free',
#  'Brutal IPA',
#  'Brutus',
#  'Bryce Ale Dry Hopped Edition (2015)',
#  'Bubble Gose',
#  'Bucanero Fuerte / Cubanero Fuerte',
#  'Budweiser',
#  'Budweiser Budvar B:DARK / Czechvar B:DARK',
#  'Budweiser Budvar B:ORIGINAL / Czechvar B:ORIGINAL',
#  'Buena Esperanza',
#  'Building Bridges',
#  'Bundesbar Pils Classic',
#  'Burge Meester',
#  'Burge Meester Special',
#  'Burro de Sancho Roja Ale',
#  'Burro de Sancho Rubia Ale',
#  'Bush Ambrée',
#  'Bustar Pale Ale',
#  'Bzart Lambiek Millésime (2013)',
#  'CAKE',
#  'CCCP',
#  'CPA - Cántabra Pale Ale',
#  'Cabrona',
#  'Cali American Pale Ale',
#  'California Sunshine APA',
#  'Calypso A.C.A.B.',
#  'Canal Dive Brown Ale',
#  'Cannabia',
#  'Cannonball',
#  'Canuck Pale Ale',
#  'Cappra',
#  'Carajillo Stout',
#  'Caribbean Rumstout',
#  'Carling',
#  'Carlsberg',
#  'Carmen White IPA',
#  'Carrie',
#  'Casablanca',
#  'Cascabel Mexican Lager',
#  'Castellana Trigo',
#  'Castiza',
#  'Category 3 IPA',
#  'Cedar & Stone',
#  'Celestial Dawn Speedway Stout',
#  'Centea',
#  'Centennial IPA',
#  'Cereal Killer',
#  'Ceriux Rubia',
#  'Ceriux Tostada',
#  'Cerveja Cristal',
#  'Cerveza Casa De Alba',
#  'Cerveza Sin Frontera (Cognac Barrel Aged)',
#  'Cerveza de Temporada: Hazy American Pale Ale',
#  'Chamberí',
#  'Charma (Χάρμα) Blond',
#  'Charma (Χάρμα) Dunkel',
#  'Chañar',
#  'Check In IPA',
#  'Cheli',
#  'Chelita',
#  'Cherry Sour',
#  'Cherry Twins',
#  'Chieftain',
#  'Chili Hammer',
#  'Chimay Bleue (Grande Réserve) (2014)',
#  'Chimay Cinq Cents (White)',
#  'Chimay Red / Rouge / Rood (Première)',
#  'Chipys',
#  'Chocolate Birthday',
#  'Choconut',
#  'Christian Bale Ale',
#  'Chueca',
#  'Chula',
#  'Chula IPA',
#  'Chula Tostada',
#  'Cierva - Blond Ale',
#  'Cierva - Saison',
#  'Ciney Blonde',
#  'Cisk Lager',
#  'Citra',
#  'Citra Ass Down',
#  'Citra Fog',
#  'Citra Gose',
#  'Citra IPA',
#  'Citra IPA (2019)',
#  'Citra Pop Corn',
#  'Citra Small IPA',
#  'CitraMango Juice IPA',
#  'Citrash',
#  'Citrus Mistress IPA',
#  'City of the Dead',
#  'Classic Gueuze',
#  'Classic Gueuze (2016)',
#  'Clausthaler Original / Premium',
#  'Clock APA',
#  'Clockwork Tangerine',
#  'Clwb Tropica',
#  'Coastal Gose',
#  'Cobra',
#  'Cobra Premium',
#  'Coco Chango',
#  'Cocoa Wonderland',
#  'Coffee Pale',
#  'CoffeeBomb',
#  'Colibrí',
#  'Colonial Hipster',
#  'Columbus Goes North',
#  'Combo',
#  'Come In Number 51',
#  'Conan DIPA',
#  'Confidence',
#  'Corgoň 10%',
#  'Corgoň 4sladový',
#  'Corsendonk Agnus Tripel / Abbey Pale Ale',
#  'Corsendonk Pater Dubbel / Abbey Brown Ale',
#  'Costa Brava',
#  'Costa Oeste',
#  'Cottolengo',
#  'Cowboys From Hellveticus',
#  'Cowboys From Hops',
#  'Cowhops From Hell',
#  'Crafty Dan 13 Guns',
#  'Crafty Dan Big Ben',
#  'Crazy Crown',
#  'Crazy Lupulo',
#  'Cream Bee',
#  'Cream Stout',
#  'Creamfields',
#  'Creature',
#  'Credo',
#  'Cretan Kings Zythos',
#  'Criolla',
#  'Criptojuice',
#  'Criss Cross',
#  'Cristal',
#  'Crooked Moon dIPA',
#  'Crooked Tree IPA',
#  'Cruz Del Sur',
#  'Cruzcampo Gran Reserva',
#  'Cruzcampo Light',
#  'Cruzcampo Pilsen',
#  'Cruzial',
#  'Cucapá Chupacabras Pale Ale',
#  'Cucapá Runaway IPA',
#  'Cunning Cougar',
#  'Curmudgeon IPA',
#  'Cusqueña Dorada',
#  'Cuvée De Ranke',
#  'Cuvée Delphine',
#  "Cuvée d'Erpigny Sauternes",
#  'Cybernaut',
#  'Cyclope Bêta IPA',
#  'D.I.P.A.',
#  'DAB Export / Dortmunder Export',
#  'DOLINA Belgian Dubbel',
#  'DRIPA',
#  'Daemon #3 Nidhoggr - Imperial Brown Ale',
#  "Dale's Pale Ale",
#  'Dalva',
#  'Dangermousse 2019',
#  'Dangerously Close To Stupid',
#  'Dank & Juicy',
#  'Dark Arts',
#  'Dark City 2018 // Crème du Cacao, Vanilla & Butterscotch Imperial Stout // Devils Delight // Lervig Aktiebryggeri',
#  'Dark Humor Club - Bourbon Vanilla',
#  'Dark Lager (Černý ležák)',
#  'Dark Matter',
#  'Datisandere Koekoek',
#  'Daura',
#  'Daura Märzen',
#  'Dead Rabbit',
#  'Deception Session IPA',
#  'Delirium Red',
#  'Delirium Tremens',
#  'Desperados Original',
#  'Dessert In A Can - Pecan & Maple Pie',
#  "Devil's Answer",
#  "Devil's DIPA",
#  "Devil's Pale Ale 666",
#  'Devin',
#  'Dia Especial 5,6%',
#  'Dia Forte 8% / Dia Extra 8%',
#  'Dia Lager',
#  'Diablos Joe!',
#  'Diabolus 2015',
#  'Diabräu 1516',
#  'Diaguitas #33 Single Hop Cascade',
#  'Dirty Harry',
#  'Divide & Conquer Black IPA',
#  'Divine Road',
#  'Django',
#  'Django R.',
#  'Doble Mad',
#  "Dog's Nose Spiced Gin",
#  'Doggie Style',
#  "Don't Gose Towards The Light",
#  'Doppel-Hirsch Heller Bock',
#  'Dorada Especial',
#  'Dorada Especial Roja',
#  'Dortoka',
#  'Dos Equis Lager Especial',
#  'Double Baden IPA',
#  'Double IPA',
#  'Double Saison Du Bout Du Monde Acidulée',
#  'Dozer Pils',
#  'Dreher Classic',
#  "Drink'in The Sun (0.3%)",
#  'Drinking Like A Fish',
#  'Drunken Sailor',
#  'Duchesse de Bourgogne',
#  'Duckstein Weizen',
#  'Duff Beer',
#  'Dumbstruck',
#  'Duvel',
#  'Duvel Tripel Hop Citra',
#  'EPA!',
#  'EX 1 IPA Seve-Boris',
#  'EZA Hellenic Pilsener Beer',
#  'Earl Phantom',
#  'Easy Livin Pils',
#  'Easy Up Pale Ale',
#  'Echoes of Vastness',
#  'Edelweiss Hofbräu',
#  'Edición Limitada Navidad',
#  'Edición Navidad Especial 36 (2018)',
#  'Effortless Grapefruit Session IPA',
#  'Eight-Ball Stout',
#  'El Alcázar',
#  'El Alcázar (6%)',
#  'El Aleph',
#  'El Corte Inglés 75 Aniversario',
#  'El Corte Inglés Cerveja Beer Lager Type',
#  'El Patron',
#  'Electric India',
#  'Elvis Juice',
#  'Ename Blond',
#  'Ename Dubbel',
#  'Ename Pater',
#  'Ename Tripel',
#  'Entropia',
#  'Envy (The Sinner Series)',
#  'Eoyec RedCrow IPA',
#  'Er Boquerón',
#  'Erdinger Dunkel',
#  'Erdinger Oktoberfest / Festweiße',
#  'Erdinger Pikantus',
#  'Erdinger Weißbier / Hefe-Weizen',
#  'Eriksberg Karaktär',
#  'Erzulie',
#  'Escape to Colorado IPA',
#  'Escudo',
#  'Eskombro',
#  'Especial',
#  'Especial 1516',
#  'Espiga Garage IPA',
#  'Esquelbécoise',
#  'Essence',
#  'Estrella Damm',
#  'Estrella Damm Inedit',
#  'Estrella Del Sur',
#  'Estrella Galicia Especial',
#  'Estrella Levante',
#  'Estrella Levante Sin Alcohol',
#  'Estrella Madrid',
#  'Eternal',
#  'Eternal Sunshine',
#  'Europa',
#  'Eurotrash Pilz',
#  'Even More Jesus',
#  'Evergreen',
#  'Evergreen IPA',
#  'Everyday IPA',
#  'Evil Cousin',
#  'Evil Is In A Midnight Mash',
#  'Evil Twin',
#  'Expedition Stout',
#  'Export India Porter',
#  'Export Porter 1750',
#  'Export Stout London 1890',
#  'Extasis',
#  'Extra 7%',
#  'Extra Dry',
#  'Extra Horny',
#  'Extra Smooth Ale',
#  'FIX Hellas',
#  'FL(IPA)',
#  'FRESH',
#  'Fabián tmavý 14%',
#  'Faith',
#  'Fantasma',
#  'Fantôme (Saison)',
#  'Farewell To Arms',
#  'Farmhouse IPA',
#  'Faro',
#  'Faxe Premium',
#  'Fibonacci',
#  'Finestkind IPA',
#  'First Blow',
#  'First Frontier IPA',
#  'Fischer Pilsener',
#  'Fishman',
#  'Five Against One - 5 vs 1',
#  "Five o'Clock Shadow",
#  'Flying Rabbit',
#  'Flyktsoda IPA',
#  'Focal Banger',
#  'Folixa',
#  'Fortunate Islands with Grapefruit Zest',
#  "Foster's Lager",
#  "Fou' Foune",
#  'Four - Russian Imperial Stout',
#  'Four Layer Cake',
#  'Framboise (2016)',
#  'Framboise Boon',
#  'Franziskaner Premium Weissbier Dunkel',
#  'Franziskaner Premium Weissbier Naturtrüb',
#  'Franziskaner Weissbier Alkoholfrei',
#  'Fresh',
#  "Friday's Pale Ale",
#  'Friends With Benefits',
#  'Frucht: Guava (2018)',
#  'Fruitesse',
#  'Fuck Art - The Heathens Are Coming',
#  'Fuerteventura Pale Ale',
#  'Full Sail',
#  'Fully Morangas',
#  'Fun House',
#  'Funk X Punk',
#  'Fuzeta',
#  'Fyr & Flamme',
#  'G de Goudale Grand Cru - Citra & Amarillo (2014)',
#  'GARAGE IPA',
#  'Galactic Nuts',
#  'Galaxy IPA',
#  'Galerna',
#  'Galway Hooker Irish Pale Ale',
#  'Galáctica',
#  'Game On',
#  'Gamma',
#  'Gamma Ray',
#  'Ganzúa',
#  'GarIpa',
#  'Garden of Eden',
#  'Gatza Gose',
#  'Gentle Bastard',
#  'Gentse Strop',
#  'Georges Pils',
#  'Gerds Raspberry Sour',
#  'Germania Pilsner',
#  'Geuze Mariage Parfait',
#  'Ghost Ship',
#  'Gijtlijster',
#  "Gimme Hop Jo'Anna",
#  'Ginger Pale Ale',
#  'Ginie (In A Bottle)',
#  'Gluten Free Blonde',
#  'Gluten Free Lager (Bezlepkový ležák)',
#  'Gluttony (The Sinner Series)',
#  'Glück',
#  'Gnomegang',
#  'Go West! IPA',
#  'God Save the Hoppy (Gluten Free)',
#  'God Save the New England IPA 2.0',
#  'God Save the Oatmeal Pale Ale',
#  'Gold',
#  'Gold Fassl Zwickl',
#  'Golden Ale',
#  'Golden Ape',
#  'Golden Beach',
#  'Golden Nugget',
#  'Golden State Of The Oak',
#  "Gollem's Precious IPA",
#  'Goma 2',
#  'Gonzo Imperial Porter',
#  'Goose IPA',
#  'Gordon Finest Chrome',
#  'Gordon Finest Titanium',
#  'Gose',
#  'Gose Margarita',
#  'Gose To Hollywood',
#  'Gose With Raspberries',
#  'Gouden Carolus Christmas / Noël',
#  'Gouden Carolus Classic',
#  'Gouden Carolus Whisky Infused',
#  'Goudenband',
#  'Gozer',
#  'Gozer Bowmore Barrel Aged',
#  'Gran Torobayo',
#  'Grand Cru Bruocsella Lambic Bio',
#  'Grand-Am™',
#  'Grapefruit Llipa!',
#  'Grave Dancer',
#  'Great Escape',
#  'Great Gig In The Sky',
#  'Greco',
#  'Greed (The Sinner Series)',
#  'Green Devil IPA',
#  'Green Go',
#  'Green Mountain',
#  'Green Zebra',
#  'Green, Green Banshee',
#  'Grevensteiner Original Naturtrübes Landbier',
#  'GreyJoy',
#  'Grimbergen Dubbel',
#  'Gringaza',
#  'Grizzly 12°',
#  'Grolsch Premium Lager',
#  'Group Therapy',
#  'Guanabana Mañana',
#  'Guardian of Peace',
#  'Guerrilla',
#  'Gueuze 100% Lambic Bio',
#  'Guillotine Gose',
#  'Guinness Draught',
#  'Guinness Original (Europe)',
#  'Guinness Special Export',
#  'Gulden Draak (2016)',
#  'Gulden Draak 9000 Quadruple',
#  'Gulden Draak Classic',
#  'Gulpener Ur-Hop',
#  'Gulpener Ur-Weizen',
#  'Guns &  Hops (Cover Series)',
#  'Gunslinger',
#  'Gurugú',
#  'GutBier Янтарное',
#  'Gösser NaturRadler',
#  'Gösser Spezial',
#  'H11',
#  'HAZY WAY NEW ZEALAND IPA',
#  'HELL',
#  'HIPÓTESIS American IPA',
#  'HOP',
#  "HORAL's Oude Geuze Mega Blend 2015",
#  'HUE',
#  'Haandgranat',
#  'Half Mast',
#  'Hallo Ich Bin Berliner Weisse Blood Orange',
#  'Hamabost',
#  'Hamer & Sikkel',
#  'Hammurapi +21',
#  'Hanalei Island IPA',
#  'Hanami',
#  'Hannen Alt',
#  'Happy Otter',
#  'Hard Cider Dry / Sidra Seca',
#  'Hard Cider Extra / Sidra Extra (Ecológica)',
#  'Hard Cider Pear / Sidra con Pera',
#  'Hard Cider Sweet / Sidra Dulce',
#  'Hard Coal Stout',
#  'Hardcore IPA',
#  'Harria',
#  'Harrie',
#  'Harvest',
#  'Harvest IPA (Mosaic Saison)',
#  'Hazelnut Brown Nectar',
#  'Hazy Vibes: Columbus & Amarillo',
#  'Head Stock',
#  'Headless',
#  'Heart & Soul',
#  'Heathen',
#  'Hefe-Weißbier Dunkel',
#  'Heineken',
#  'Heisenbierg',
#  'Hel & Verdoemenis',
#  'Hel & Verdoemenis Bourbon Barrel Aged',
#  'Helleketel',
#  'Hello My Name Is Little Ingrid',
#  'Hello Nasty Dry Hopped Sour',
#  'Hemel & Aarde',
#  'Hemisphere Session IPA',
#  'Hentai',
#  'Hepenheimer',
#  'Hibiscus Mordvic (BBF 2017)',
#  'High Hops 6',
#  'High Wire',
#  'High Wire Grapefruit',
#  'Hip Hops',
#  'Hippy Berliner',
#  'Hitachino Nest Espresso Stout',
#  'Hitachino Nest Japanese Classic Ale',
#  'Hitachino Nest Non Ale',
#  'Hitachino Nest Pale Ale',
#  'Hitachino Nest White Ale',
#  'Hitachino Nest XH',
#  'Hite',
#  'Hobgoblin Legendary Ruby Beer',
#  'Hobo Chic',
#  'Hoegaarden Grand Cru',
#  'Hoegaarden Wit / Blanche',
#  'Hofbräu Oktoberfestbier',
#  'Hoi Dit is Hop. (Tomahawk)',
#  'Holandesa',
#  'Holsten Pilsener',
#  'Holy Cowbell India Stout',
#  'Honey Blonde Ale',
#  'Hop & Liefde / Pale Ale Citra',
#  'Hop Art',
#  'Hop Burn High',
#  'Hop Candy',
#  'Hop Doom',
#  'Hop Fiction',
#  'Hop Fiction Pale Ale',
#  'Hop Highway IPA',
#  'Hop Hunter',
#  'Hop Hunters Winter India Pale Lager',
#  'Hop Juice',
#  'Hop Kine',
#  "Hop Ottin' IPA",
#  'Hop Sexion IPA',
#  'Hop Shock',
#  'Hop Time',
#  'Hop Zij Met Ons',
#  'Hop-Fx (Cover Series)',
#  'Hopfather',
#  'Hopfenweisse (TAP05)',
#  'Hopnotic Waves',
#  'Hoponius Union',
#  'Hopoplata',
#  "Hoppin' To Heaven IPA",
#  'Hoppiness',
#  'Hoppoil',
#  'Hopportunity Knocks',
#  'Hoppy',
#  'Hoppy Beerday',
#  'Hoppy Christmas',
#  'Hoppy Joe',
#  'Hoppy Lager',
#  "Hoppy Lovin' Christmas",
#  'Hoppy Mondays',
#  'Hops & Cops',
#  'Hops Tree Chili',
#  'Hops!... I Did It Again',
#  'Hopster Party',
#  'Hoptical Illusion',
#  'Hoptimista IPA',
#  'Hoptopod',
#  'Hopworks IPA',
#  'Hostage Rye IPA',
#  'Hot Smokey Sanchez',
#  'Hot Wrath? Cold Bath',
#  'Houblon Chouffe',
#  'How the Light Gets In',
#  'Human Cannonball',
#  'Hundelufter Bajer',
#  "Hunter's Gold",
#  'Hyperactive',
#  'Hypnotist',
#  'Hørny Pilsner (Høppy Pilsner)',
#  'Hüll Melon Saison',
#  'I Wish Gluten Free IPA',
#  'I.P.A.',
#  'IBUprofano',
#  'III Anniversary Harvest',
#  'IJwit',
#  'IMP5RIO (Quinto Império) - Port BA Imperial Saison',
#  'IN GREEN WE TRUST',
#  'IPA',
#  'IPA 2',
#  'IPA 3',
#  'IPA 4',
#  'IPA 5',
#  'IPA 6',
#  'IPA 7',
#  'IPA 8',
#  'IPA Amarillo',
#  'IPA Dry Hopping',
#  'IPAnema',
#  'Ich Bin Ein Berryliner',
#  'Ichiban (Ichiban Shibori) (一番搾り)',
#  'Idaho Picnic',
#  'Idiot IPA',
#  'Illusion',
#  'Imparable',
#  'Imparable Pomelo Edition',
#  'Imperator Bałtycki',
#  'Imperial Biscotti Break',
#  'Imperial Brown Stout London 1856',
#  'Imperial Entanglement',
#  'Imperial Gianduja Stout ',
#  'Imperial IPA',
#  'Imperial Red IPA',
#  'Imperial Stout',
#  'Imperial Stout (2014)',
#  'Imperial Stout Whisky Barrel Aged',
#  'Imperialist',
#  'Imprl Saisn',
#  'In I Dimman',
#  'India Ale',
#  'India Pale Ale',
#  'India Pale Ale / London IPA',
#  'India Pale Ale Centennial',
#  'India Pale Ale Citra Ella Galaxy',
#  'India Pale Ale Citra Motueka',
#  'India Pale Ale Citra Summit',
#  'India Pale Ale Citra Zeus',
#  'India Pale Ale Galaxy',
#  'India Pale Ale Galaxy Mosaic',
#  'India Pale Ale Galaxy Mosaic Zeus',
#  'India Pale Ale Is Not A Crime',
#  'India Pale Ale Mosaic Citra Amarillo',
#  'India Pale Ale Mosaic Columbus',
#  'India Pale Ale Simcoe',
#  'India Pale Ale Vic Secret',
#  'India Pale Weizen',
#  'Indian Tribute',
#  'Infusion A: Peanut Butter Chocolate Coffee Porter',
#  'Inhaler',
#  'Inkasso IPA',
#  'Inner Circle',
#  'Insider',
#  'Into the Tunnel',
#  'Invasion',
#  'Investor IPA',
#  'Ipa-nema 2.0',
#  'Ipanema',
#  'Is That Sabro!?',
#  'Islander IPA',
#  'Isleña',
#  "It's StillWeisse",
#  'Ivan Dryhop DDH IPA',
#  'Jack Brand Innovation',
#  'Jack Hammer',
#  'Jackie Brown',
#  'Jacobus Pale Ale (RPA)',
#  'Jade',
#  'Jagged Edge IPA',
#  'Jai Alai',
#  'Jai JAI',
#  'Jaipur',
#  'Jakehead',
#  'Jam On Toast',
#  'Jam72',
#  'Jambo!',
#  'Jamonera',
#  'Jasmine IPA',
#  'Jelen Pivo',
#  'Jever Fun',
#  'Jever Pilsener',
#  'Ježek 11%',
#  'Joey Greenhorn Restless IPA',
#  'Johannes Cyder Suchý',
#  'Johnny Crash',
#  'Joost Mag Het Weten',
#  'Juan Morr',
#  'Judas',
#  'Juice Junkie',
#  'Juicy Confessions',
#  'Juicy Delight',
#  'Juniper Pale Ale',
#  'Jupiler',
#  'Jupiter',
#  'KM. 100',
#  'Kaapse Bea',
#  'Kadabra Belgian White',
#  'Kadabra IPA',
#  'Kadabra Red Ale',
#  'Kaiser Fasstyp / Kaiser Bier',
#  'Kaiser Pilsner',
#  'Kajun Moonshiner IPA',
#  'Kallithea Dreaming',
#  'Kaper',
#  'Kapuziner Weißbier',
#  'Karel',
#  'Karluminium',
#  'Karpackie Premium',
#  'Kashkal',
#  'Kasper',
#  'Katten DIPA',
#  'Keler 18',
#  'Kelet-Indiai Társaság',
#  'Kelt 10%',
#  'Kentucky Breakfast Stout (KBS)',
#  ...]

# %%
corr_matrix= np.corrcoef(ratings.T)
corr_matrix.shape
# Out:
# (2010, 2010)

# %%
def get_beer_similarity(beer_name):  
    '''Returns correlation vector for a beer'''
    beer_idx = list(beer_index).index(beer_name)
    return corr_matrix[beer_idx]

# %%
a=get_beer_similarity("Jamonera")
a.shape
# Out:
# (2010,)

# %%
a
# Out:
# array([-0.00613497, -0.00613497, -0.00613497, ..., -0.00613497,
#        -0.00613497, -0.00613497])

# %%
def get_beer_recommendations(stl):  
    '''given a set of beers, it returns all the beers sorted by their correlation with the style'''
   
    beer_similarities = np.zeros(corr_matrix.shape[0])
    for Id in stl:
        beer_similarities = beer_similarities + get_beer_similarity(Id)
    similarities_df = pd.DataFrame({
        'beer_name': beer_index,
        'sum_similarity': beer_similarities
        })
    similarities_df = similarities_df[~(similarities_df.beer_name.isin(stl))]
    similarities_df = similarities_df.sort_values(by=['sum_similarity'], ascending=False)
    return similarities_df.beer_name.head(6)

# %%
sample_style = 'IPA - American'
df[df.beer_type==sample_style].sort_values(by=['rating_score'], ascending=False)
# Out:
#                    beer_name       beer_type  beer_abv  beer_ibu  \
# 1362             Bomber IPA   IPA - American       6.8        60
# 2111          Primacy Effect  IPA - American       7.0         0
# 687            Big Swell IPA  IPA - American       6.8        70
# 1554   New England Juicy Ale  IPA - American       6.0         0
# 2001            Salda Badago  IPA - American       7.0        40
# ...                      ...             ...       ...       ...
# 1149  X Kolsvart Lakrits IPA  IPA - American       6.7         0
# 1247                   IPA 7  IPA - American       7.0       100
# 634                    Salem  IPA - American       5.5        42
# 2189                     IPA  IPA - American       7.0        55
# 2282           Hoppy Beerday  IPA - American       6.0        60
#
#       rating_score  global_rating_score  \
# 1362          5.00                 3.89
# 2111          5.00                 3.74
# 687           5.00                 3.68
# 1554          5.00                 3.58
# 2001          5.00                 3.81
# ...            ...                  ...
# 1149          1.25                 3.75
# 1247          1.00                 3.80
# 634           0.75                 2.99
# 2189          0.75                 3.16
# 2282          0.25                 3.34
#
#                                               photo_url
# 1362  https://untappd.s3.amazonaws.com/photo/2016_11...
# 2111  https://untappd.s3.amazonaws.com/photos/2019_0...
# 687   https://untappd.s3.amazonaws.com/photo/2015_12...
# 1554  https://untappd.s3.amazonaws.com/photo/2017_04...
# 2001  https://untappd.s3.amazonaws.com/photos/2018_1...
# ...                                                 ...
# 1149  https://untappd.s3.amazonaws.com/photo/2016_08...
# 1247  https://untappd.s3.amazonaws.com/photo/2016_09...
# 634   https://untappd.s3.amazonaws.com/photo/2015_10...
# 2189  https://untappd.s3.amazonaws.com/photos/2019_0...
# 2282  https://untappd.s3.amazonaws.com/photos/2020_0...
#
# [381 rows x 7 columns]

# %%
sample_style_beers = df[df.beer_type==sample_style].beer_name.tolist()  
recommendations = get_beer_recommendations(sample_style_beers)
recommendations
# Out:
# 915             India Ale
# 893       IPA Dry Hopping
# 320     Brooklyn East IPA
# 1318       Old Empire IPA
# 1463           Proper Job
# 979               KM. 100
# Name: beer_name, dtype: object

# %%
df1=df[df.beer_type==sample_style].head(6)
df1=df1.filter(items=['beer_type'])
df1.reset_index(inplace=True)
df1
# Out:
#    index       beer_type
# 0     15  IPA - American
# 1     26  IPA - American
# 2     32  IPA - American
# 3     39  IPA - American
# 4     57  IPA - American
# 5     62  IPA - American

# %%
df_final=recommendations.to_frame()
df_final.reset_index(inplace=True)
df_final
# Out:
#    index          beer_name
# 0    915          India Ale
# 1    893    IPA Dry Hopping
# 2    320  Brooklyn East IPA
# 3   1318     Old Empire IPA
# 4   1463         Proper Job
# 5    979            KM. 100

# %%
df_final_test=pd.concat([df1['beer_type'], df_final['beer_name']], axis=1)

# %%
df_final_test
# Out:
#         beer_type          beer_name
# 0  IPA - American          India Ale
# 1  IPA - American    IPA Dry Hopping
# 2  IPA - American  Brooklyn East IPA
# 3  IPA - American     Old Empire IPA
# 4  IPA - American         Proper Job
# 5  IPA - American            KM. 100

# %%
df_filtered = df[df['beer_type'] == "IPA - American"]
df_filtered.head(10)
# Out:
#                  beer_name       beer_type  beer_abv  beer_ibu  rating_score  \
# 15    Smashbomb Atomic IPA  IPA - American       6.0        72          4.50
# 26            Fyr & Flamme  IPA - American       6.5        66          4.50
# 32          Hop Ottin' IPA  IPA - American       7.0        80          4.00
# 39                 942 IPA  IPA - American       7.0        51          4.25
# 57              Galaxy IPA  IPA - American       6.5       100          4.00
# 62   India Pale Ale Galaxy  IPA - American       6.9         0          4.50
# 83           Snake Dog IPA  IPA - American       7.1        60          3.50
# 89   Jack Brand Innovation  IPA - American       6.7         0          3.00
# 91                     IPA  IPA - American       6.8        35          2.00
# 147                FL(IPA)  IPA - American       6.2        60          3.50
#
#      global_rating_score                                          photo_url
# 15                  3.66  https://untappd.s3.amazonaws.com/photo/2013_11...
# 26                  3.75  https://untappd.s3.amazonaws.com/photo/2013_12...
# 32                  3.56  https://untappd.s3.amazonaws.com/photo/2013_12...
# 39                  3.81  https://untappd.s3.amazonaws.com/photo/2013_12...
# 57                  3.58  https://untappd.s3.amazonaws.com/photo/2013_12...
# 62                  3.90  https://untappd.s3.amazonaws.com/photo/2014_01...
# 83                  3.60  https://untappd.s3.amazonaws.com/photo/2014_01...
# 89                  3.45  https://untappd.s3.amazonaws.com/photo/2014_01...
# 91                  3.76  https://untappd.s3.amazonaws.com/photo/2014_01...
# 147                 3.71  https://untappd.s3.amazonaws.com/photo/2014_02...

# %%
items = sorted(df['beer_type'].unique().tolist())

def view(x=''):
    if x==x: return(get_beer_recommendations(df[df.beer_type==x].beer_name.tolist()))
     
    
w = widgets.Select(options=items)
interactive(view, x=w)
# Out:
# interactive(children=(Select(description='x', options=('Altbier', 'American Wild Ale', 'Australian Sparkling A…

# %%
def get_top_beers (a):
    favoured_beer_index = list(beer_index).index(a)
    P = corr_matrix[favoured_beer_index]
#sólo devolvemos las cervezas con la mayor correlación con Jamonera
    return(list(beer_index[(P>0.5) & (P<1.0)][:5]))

# %%
get_top_beers('Fyr & Flamme')
# Out:
# ['7 Hop IPA', 'Anchor IPA', 'Bang! Bang!', 'Betty Juice', 'Big Swell IPA']

# %%
items2 = sorted(df['beer_name'].unique().tolist())

def view(x=''):
    if x==x: return(get_top_beers(x))
     
    
w = widgets.Select(options=items2)
interactive(view, x=w)
# Out:
# interactive(children=(Select(description='x', options=(' Amber Lager (Jantarový ležák)', ' Celebration Lager (…
